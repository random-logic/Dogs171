# %% [markdown]
# # Preprocessing

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /home/random01/anaconda3/envs/ecs171/lib/python3.11/site-packages (10.2.0)

# %%
import os
import pandas as pd
from PIL import Image
import numpy as np

from keras.applications.vgg16 import preprocess_input
from keras.utils import img_to_array
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Flatten
# Out:
# 2024-03-11 03:07:26.721913: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-11 03:07:26.745209: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-11 03:07:26.745229: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-11 03:07:26.745768: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 03:07:26.749702: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 03:07:27.233281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Location of images and corresponding metadata
image_dir = 'images/Images'
annotation_dir = 'annotations/Annotation'
folder_to_save = 'theFeaturesByBreed'
SHAPE = (224, 224)

# %%
# Load VGG16 model without top layers
base_model = VGG16(weights='imagenet', include_top=True, classifier_activation=None)

# Freeze the convolutional base
base_model.trainable = False

# Create a new model to extract features
feature_extraction_model = Sequential([
    base_model,
    Flatten()
])
# Out:
# 2024-03-11 03:07:27.862113: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:27.876096: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:27.876134: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:27.876938: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:27.876969: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:27.876986: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:28.035433: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:28.035488: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:28.035495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-11 03:07:28.035522: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-11 03:07:28.035540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9536 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
def predict(img):
    return feature_extraction_model.predict(np.expand_dims(img, axis = 0))[0]

# %%
# Traverse through image directory

i = 0
for breed_folder in os.listdir(image_dir):
#     if i > 10:  # Used for testing a subset
#         break
    breed_path = os.path.join(image_dir, breed_folder)
    if os.path.isdir(breed_path):
        breed = breed_folder.split('-')[-1].lower()  # Lowercase for uniformity
        
        # double check if we already wrote data for this
        if os.path.exists(os.path.join(folder_to_save, breed + '.csv')):
            continue
        
        print("Breed is:", breed) 
        raw_data = []
        
        # Identify each image in the subfolder
        for image_file in os.listdir(breed_path):
            if image_file.endswith('.jpg'):
                print("Image is:", image_file)
                image_id = os.path.splitext(image_file)[0]
                image_path = os.path.join(breed_path, image_file)
                
                # Find corresponding annotation file
                annotation_file = os.path.join(annotation_dir, breed_folder, image_id)
                # print("Annotation file is:", annotation_file) # FIXME: remove or comment
                # Check if annotation file exists
                if os.path.exists(annotation_file):
                    # Read annotation file
                    with open(annotation_file, 'r') as f:
                        lines = f.readlines()
                    
                    # Extract annotation information
                    width = int(int(lines[7].split('>')[1].split('<')[0]))
                    #print(lines[7], width) # FIXME: remove
                    height = int(lines[8].split('>')[1].split('<')[0])
                    #print(lines[8], height) # FIXME: remove
                    xmin = int(lines[18].split('>')[1].split('<')[0])
                    #print(lines[18], xmin) # FIXME: remove
                    ymin = int(lines[19].split('>')[1].split('<')[0])
                    xmax = int(lines[20].split('>')[1].split('<')[0])
                    ymax = int(lines[21].split('>')[1].split('<')[0])
                    
                    # Open image and crop
                    img = Image.open(image_path)
                    img = img.crop((xmin, ymin, xmax, ymax))
                    img = img.resize(SHAPE)
                    img = img_to_array(img)
                    img = preprocess_input(img)

                    # extract features
                    features = predict(img)
                    
                    # Add the new entry to the list
                    raw_data.append({
                               'Breed': breed,
                               'Features': features
                              })
                # endif
            # endif
        # endfor
        df = pd.DataFrame(raw_data)
        df.to_csv(os.path.join(folder_to_save, breed + '.csv'), index=False)
                    
#     i+= 1
                    
del i
# Out:
# Breed is: chesapeake_bay_retriever
# Image is: n02099849_541.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_3007.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3289.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4677.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4767.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_410.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3220.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4636.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1115.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_3128.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3383.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1068.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_2706.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_1776.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_3563.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2130.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_669.jpg
# 1/1 [==============================] - 0s 18ms/step
# Image is: n02099849_1050.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3976.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_1234.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1837.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1265.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2581.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_671.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_1997.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1575.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_693.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_263.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_1922.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3753.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_4322.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3016.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3494.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_3.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_590.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_4406.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_3592.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1823.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_605.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2836.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2847.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2050.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_3940.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2416.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3203.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3207.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_2965.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_953.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1157.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4287.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_4278.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_130.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_68.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3429.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_4180.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3346.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2462.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1212.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2935.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_4498.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1349.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3645.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4215.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_4413.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_920.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3789.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3326.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_562.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_1657.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1728.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4419.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_3149.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3881.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_2944.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_193.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_216.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_338.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3897.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_110.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_415.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1278.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_43.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_463.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_696.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3810.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4348.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2092.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_4519.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_435.jpg
# 1/1 [==============================] - 0s 12ms/step
# Image is: n02099849_2068.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_501.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1536.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_2646.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_4113.jpg
# 1/1 [==============================] - 0s 21ms/step
# Image is: n02099849_448.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_513.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3718.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3616.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3680.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1523.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3723.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_687.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_1408.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4646.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3196.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2250.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1326.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3194.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2133.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4726.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3826.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_4310.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1740.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4549.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2991.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4619.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4692.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3736.jpg
# 1/1 [==============================] - 0s 12ms/step
# Image is: n02099849_2482.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1215.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_949.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_3911.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2020.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_171.jpg
# 1/1 [==============================] - 0s 12ms/step
# Image is: n02099849_3316.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4667.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_544.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_140.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3315.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1449.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2573.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2803.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_857.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3812.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_927.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2300.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1830.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1024.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2315.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_2612.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_4457.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3617.jpg
# 1/1 [==============================] - 0s 13ms/step
# Image is: n02099849_1310.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_977.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3403.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_3369.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3777.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_1645.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_493.jpg
# 1/1 [==============================] - 0s 17ms/step
# Image is: n02099849_938.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3283.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3619.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3188.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_253.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3451.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_264.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1599.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2648.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_31.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_3266.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_2375.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_3565.jpg
# 1/1 [==============================] - 0s 15ms/step
# Image is: n02099849_2153.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_727.jpg
# 1/1 [==============================] - 0s 16ms/step
# Image is: n02099849_1472.jpg
# 1/1 [==============================] - 0s 14ms/step
# Image is: n02099849_1987.jpg
# 1/1 [==============================] - 0s 15ms/step
