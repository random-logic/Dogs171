# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('features.csv')

# Extract features and labels
x = df.drop(columns=['Breed'])
y = df['Breed']

# Number of classes (breeds)
num_classes = 120

# Display the first few rows of the DataFrame
display(df.head())

# Print the number of breeds
print(f"Number of Breeds: {num_classes}")

# Create a hashmap for breed names
breed_map = {i: breed for i, breed in enumerate(y.unique(), 0)}

# Print the breed map
print("Breed Map:")
for key, value in breed_map.items():
    print(f"{key}: {value}")

# Example usage:
# Get the breed corresponding to the 31st entry in df['Breed']
index = 30
print(f"\nBreed at index {index}: {breed_map[index]}")
# Out:
#                 Breed  Feature 0  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0  scottish_deerhound   2.687539   3.932317  -3.243325   2.071663   6.351608
# 1  scottish_deerhound  12.965803  -0.565486   0.352435  -4.360752   4.687381
# 2  scottish_deerhound  22.904961  -2.710478   4.040229   1.884548  11.017559
# 3  scottish_deerhound  19.225068   4.136729   1.859559  -2.977302   8.724263
# 4  scottish_deerhound  33.098792   0.000445  10.866465   3.810472   9.132536
#
#    Feature 5  Feature 6  Feature 7  Feature 8  ...  Feature 90  Feature 91  \
# 0 -13.571045   3.075167  -2.453783  -4.240095  ...    1.208537    0.615094
# 1  -6.993444   0.196068  -6.633534  -1.871662  ...   -0.742694   -0.172587
# 2  -7.424705   0.592055   8.473251   4.439982  ...    0.643105   -0.818507
# 3  -4.673608   1.022031  -3.917459  -1.901546  ...   -1.538805   -1.504374
# 4  -7.464697   2.522165   5.504714   0.360156  ...    1.228905    0.348156
#
# ...

# %%
# Define the filename for the output Python file
output_file = 'breed_map.py'

# Write the breed map to the output file
with open(output_file, 'w') as f:
    f.write('breed_map = {\n')
    for key, value in breed_map.items():
        f.write(f"    {key}: '{value}',\n")
    f.write('}\n')

print(f"Breeds map has been written to {output_file}.")
# Out:
# Breeds map has been written to breed_map.py.
