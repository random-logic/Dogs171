# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
from PIL import Image

# %%
# print(os.listdir())
# x = os.path.join('annotations', 'Annotation')
# print(x)
# os.listdir(x)

# %%
# Define the paths
image_dir = 'images/Images'
annotation_dir = 'annotations/Annotation'

# Initialize an empty DataFrame to store the data
# data = {'ID': [],
#         'Breed': [],
#         'Image': [],
#         'Path': [],
#         'Width': [],
#         'Height': [],
#         'Xmin': [],
#         'Xmax': [],
#         'Ymin': [],
#         'Ymax': []}
# df = pd.DataFrame(data)
raw_data = []

# %%
#print(os.listdir(image_dir))
#print(os.listdir(annotation_dir))

# %%
# Traverse through image directory

i = 0
for breed_folder in os.listdir(image_dir):
#     if i > 10:  # Used for testing a subset
#         break
    breed_path = os.path.join(image_dir, breed_folder)
    if os.path.isdir(breed_path):
        breed = breed_folder.split('-')[-1].lower()  # Lowercase for uniformity
        print("Breed is:", breed) # FIXME: remove or comment
        
        # Identify each image in the subfolder
        for image_file in os.listdir(breed_path):
            if image_file.endswith('.jpg'):
                image_id = os.path.splitext(image_file)[0]
                image_path = os.path.join(breed_path, image_file)
                
                # Find corresponding annotation file
                annotation_file = os.path.join(annotation_dir, breed_folder, image_id)
                # print("Annotation file is:", annotation_file) # FIXME: remove or comment
                # Check if annotation file exists
                if os.path.exists(annotation_file):
                    # Read annotation file
                    with open(annotation_file, 'r') as f:
                        lines = f.readlines()
                    
                    # Extract annotation information
                    width = int(int(lines[7].split('>')[1].split('<')[0]))
                    #print(lines[7], width) # FIXME: remove
                    height = int(lines[8].split('>')[1].split('<')[0])
                    #print(lines[8], height) # FIXME: remove
                    xmin = int(lines[18].split('>')[1].split('<')[0])
                    #print(lines[18], xmin) # FIXME: remove
                    ymin = int(lines[19].split('>')[1].split('<')[0])
                    xmax = int(lines[20].split('>')[1].split('<')[0])
                    ymax = int(lines[21].split('>')[1].split('<')[0])
                    
                    # Open image and crop
                    img = Image.open(image_path)
                    img_cropped = img.crop((xmin, ymin, xmax, ymax))
                    #img.show()
                    #img_cropped.show()
                    
                    # Add the new entry to the list
                    raw_data.append({'ID': image_id,
                                      'Breed': breed,
                                      'Image': img_cropped,
                                      'Path': image_path,
                                      'Width': width,
                                      'Height': height,
                                      'Xmin': xmin,
                                      'Xmax': xmax,
                                      'Ymin': ymin,
                                      'Ymax': ymax})
                    
#     i+= 1
# Out:
# Breed is: dhole
# Breed is: scottish_deerhound
# Breed is: basset
# Breed is: briard
# Breed is: italian_greyhound
# Breed is: rottweiler
# Breed is: yorkshire_terrier
# Breed is: bernese_mountain_dog
# Breed is: pembroke
# Breed is: maltese_dog
# Breed is: malinois
# Breed is: bluetick
# Breed is: whippet
# Breed is: norwegian_elkhound
# Breed is: tan_coonhound
# Breed is: newfoundland
# Breed is: haired_fox_terrier
# Breed is: toy_terrier
# Breed is: gordon_setter
# Breed is: miniature_pinscher
# Breed is: cocker_spaniel
# Breed is: saint_bernard
# Breed is: pomeranian
# Breed is: cardigan
# Breed is: samoyed
# Breed is: norwich_terrier
# Breed is: french_bulldog
# Breed is: bull_mastiff
# Breed is: chesapeake_bay_retriever
# Breed is: appenzeller
# Breed is: english_setter
# Breed is: mexican_hairless
# Breed is: miniature_schnauzer
# Breed is: lhasa
# Breed is: pekinese
# Breed is: leonberg
# Breed is: bedlington_terrier
# Breed is: japanese_spaniel
# Breed is: borzoi
# Breed is: redbone
# Breed is: afghan_hound
# Breed is: schipperke
# Breed is: irish_setter
# Breed is: cairn
# Breed is: airedale
# Breed is: sealyham_terrier
# Breed is: sussex_spaniel
# Breed is: irish_terrier
# Breed is: great_pyrenees
# Breed is: brittany_spaniel
# Breed is: bloodhound
# Breed is: basenji
# Breed is: chow
# Breed is: affenpinscher
# Breed is: african_hunting_dog
# Breed is: staffordshire_bullterrier
# Breed is: old_english_sheepdog
# Breed is: kuvasz
# Breed is: english_springer
# Breed is: doberman
# Breed is: clumber
# Breed is: dandie_dinmont
# Breed is: border_collie
# Breed is: entlebucher
# Breed is: australian_terrier
# Breed is: tibetan_terrier
# Breed is: coated_retriever
# Breed is: ibizan_hound
# Breed is: beagle
# Breed is: blenheim_spaniel
# Breed is: otterhound
# Breed is: lakeland_terrier
# Breed is: walker_hound
# Breed is: boxer
# Breed is: haired_pointer
# Breed is: pug
# Breed is: scotch_terrier
# Breed is: kerry_blue_terrier
# Breed is: irish_wolfhound
# Breed is: english_foxhound
# Breed is: coated_retriever
# Breed is: siberian_husky
# Breed is: west_highland_white_terrier
# Breed is: standard_poodle
# Breed is: labrador_retriever
# Breed is: saluki
# Breed is: norfolk_terrier
# Breed is: border_terrier
# Breed is: toy_poodle
# Breed is: komondor
# Breed is: kelpie
# Breed is: shetland_sheepdog
# Breed is: silky_terrier
# Breed is: brabancon_griffon
# Breed is: vizsla
# Breed is: american_staffordshire_terrier
# Breed is: collie
# Breed is: rhodesian_ridgeback
# Breed is: chihuahua
# Breed is: eskimo_dog
# Breed is: keeshond
# Breed is: welsh_springer_spaniel
# Breed is: standard_schnauzer
# Breed is: malamute
# Breed is: weimaraner
# Breed is: boston_bull
# Breed is: german_shepherd
# Breed is: golden_retriever
# Breed is: coated_wheaten_terrier
# Breed is: papillon
# Breed is: groenendael
# Breed is: miniature_poodle
# Breed is: great_dane
# Breed is: tibetan_mastiff
# Breed is: tzu
# Breed is: bouvier_des_flandres
# Breed is: greater_swiss_mountain_dog
# Breed is: irish_water_spaniel
# Breed is: giant_schnauzer
# Breed is: dingo
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_7954
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_7978
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8017
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8049
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8108
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_818
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8205
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8489
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8812
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_8825
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9098
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9293
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_936
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9429
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9467
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9551
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_963
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_968
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_9750
# Breed is: blenheim_spaniel
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1002
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1014
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1023
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1077
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1091
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1094
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1126
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1150
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_117
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_118
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1182
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1234
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1246
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_127
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1342
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_136
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1368
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1445
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1447
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1461
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1476
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1511
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1514
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1535
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1586
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1590
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1605
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1621
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1647
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_166
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1673
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1674
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1677
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1688
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_172
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1721
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_173
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1733
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1747
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1757
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1825
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1830
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1845
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1847
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1908
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1920
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1930
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1936
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1952
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1959
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_1993
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_20
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2005
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2011
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2069
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2105
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2114
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2155
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2160
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2171
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2173
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2236
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2252
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_23
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2347
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2355
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2366
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2404
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2409
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2426
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2430
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2478
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2498
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2613
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2621
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2641
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2700
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2725
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2731
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2772
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2778
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_280
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2805
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2813
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2815
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_282
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2834
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2871
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2873
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2891
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2903
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2931
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2932
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2955
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2959
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_296
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_2970
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_303
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3052
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3053
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3059
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_309
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3149
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3161
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3172
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_32
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3233
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3234
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3256
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_326
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3315
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3337
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_337
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3429
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3465
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3466
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3471
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3484
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3522
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3524
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3536
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_356
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3565
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3629
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3670
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3680
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3688
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_371
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3721
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3738
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3739
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3741
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3766
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_380
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3806
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3815
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3827
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3832
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3856
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3893
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3917
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3920
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3968
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3986
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_3989
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4024
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4026
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4041
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4045
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4077
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4084
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4120
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4133
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_414
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4148
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_416
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4177
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4199
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_421
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4213
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4219
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_422
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4220
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4226
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4265
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4298
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_4311
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_45
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_462
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_471
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_554
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_567
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_589
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_593
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_602
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_612
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_618
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_637
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_669
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_672
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_801
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_814
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_851
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_885
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_946
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_981
# Annotation file is: annotations/Annotation\n02086646-Blenheim_spaniel\n02086646_982
# Breed is: papillon
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_10147
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_10204
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_103
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1048
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1052
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1199
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1409
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1449
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1475
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1492
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1501
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1613
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1626
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1659
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1729
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1775
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1826
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1921
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1933
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1957
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_1971
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2016
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2035
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2084
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_21
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2168
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2188
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2235
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2240
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2335
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2359
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2380
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2399
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2410
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2454
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2455
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2466
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2474
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2550
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2556
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2574
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2579
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_26
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2648
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2670
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2671
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2691
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2698
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2724
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2875
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2897
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2900
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2909
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2994
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_2999
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3020
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3117
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3136
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3140
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3262
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3320
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3338
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_334
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_336
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3455
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3478
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3523
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3553
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3616
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3633
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3671
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3714
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3769
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3795
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3866
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3924
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3974
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_399
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_3991
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4011
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4182
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4210
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4296
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4330
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4373
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4388
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4424
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4441
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4488
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4505
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4514
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4518
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4542
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4551
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4607
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4609
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4623
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4790
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_485
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4883
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_4999
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5010
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5017
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5023
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5031
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5037
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5063
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5396
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5399
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_54
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5408
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5488
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5530
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5547
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5560
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_557
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5598
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5707
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_592
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5932
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5942
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_5995
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6087
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6089
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6207
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6293
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6305
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6306
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6317
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6373
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6475
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6483
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6509
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6682
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_685
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6882
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_6931
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_695
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7019
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7156
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7280
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7301
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7321
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7405
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7412
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7426
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7456
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7514
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7516
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7606
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7609
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7698
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7752
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7766
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7837
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7842
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7857
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7868
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7909
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7949
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_797
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7998
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_7999
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8047
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8091
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8120
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8194
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8209
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8241
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8342
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8354
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_847
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8573
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8590
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8606
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8613
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_862
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_865
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_881
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8866
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_8872
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9000
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9041
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9056
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9084
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9128
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9296
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9317
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_933
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9355
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9408
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9527
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9579
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9710
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_984
# Annotation file is: annotations/Annotation\n02086910-papillon\n02086910_9883
# Breed is: toy_terrier
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1004
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1206
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_133
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1386
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1468
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1482
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1520
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1577
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1658
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1666
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1703
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1724
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_178
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1792
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_1989
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2058
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2127
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2140
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2141
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2152
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2158
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2168
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_217
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2185
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2193
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2199
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_224
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2276
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2279
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_228
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2315
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2316
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2419
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2485
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2551
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2614
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_267
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2744
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2752
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2819
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2843
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2957
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_296
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_2969
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_309
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3103
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3211
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3311
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_336
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3439
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3462
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3470
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3471
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3490
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3543
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3560
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_357
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3608
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3651
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3724
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3735
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3843
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3923
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3944
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_3953
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4001
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4039
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4058
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_406
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4066
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4102
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4127
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4129
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4135
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4155
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_420
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4235
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_430
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4315
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4338
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4346
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4350
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4370
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4394
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4401
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4402
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4409
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4426
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4455
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4506
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4575
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4614
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4647
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4751
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4808
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4809
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4832
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4851
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4856
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4906
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_4987
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5017
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_505
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5196
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5203
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5219
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5224
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5305
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5306
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5325
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5347
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_538
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5383
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5386
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5407
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5439
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5499
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5541
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5626
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5661
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_568
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5701
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5756
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5838
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5840
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5843
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5847
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5849
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5860
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5887
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_5890
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6003
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6029
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6152
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6166
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6179
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6205
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6211
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6266
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6324
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6357
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6370
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6443
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6476
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6513
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6522
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6812
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6857
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6902
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_693
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_6986
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_7015
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_7037
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_7149
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_7166
# Annotation file is: annotations/Annotation\n02087046-toy_terrier\n02087046_7191
# ...
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_688
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7106
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_713
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7131
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7146
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7229
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7260
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_732
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7636
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7683
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_7894
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_791
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8063
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8290
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8315
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8362
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8465
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8631
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8682
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_875
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_8764
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_890
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_899
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_907
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_908
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_913
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_9197
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_9220
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_9229
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_93
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_9523
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_980
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_986
# Annotation file is: annotations/Annotation\n02088094-Afghan_hound\n02088094_988
# Breed is: basset
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10005
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10013
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10028
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10049
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10051
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10054
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10063
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10072
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10095
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10102
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10106
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10110
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10113
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10129
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10140
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10142
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10183
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10245
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10288
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10338
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10358
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10451
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10473
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10510
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10592
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10682
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10741
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10753
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10757
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10870
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_10932
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11113
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11124
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11136
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11148
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11200
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11204
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11223
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11281
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11318
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11339
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11383
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11393
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11505
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11511
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11522
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11542
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11635
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11846
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11849
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_11917
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12160
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12196
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12293
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12427
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12469
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12555
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12563
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_1261
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12710
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12966
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12974
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_12997
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13036
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13079
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13199
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13222
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13373
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13439
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13608
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13683
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13709
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13720
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13799
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13847
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_13908
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_1454
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_1731
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_1944
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2009
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2217
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2574
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2646
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2674
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2686
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2822
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_2879
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_305
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3066
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3079
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3359
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3475
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3579
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_363
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_3778
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_4182
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_4365
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_4374
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_490
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_517
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_5239
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_5441
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_600
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6012
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6017
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6035
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6161
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6532
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_657
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_658
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6621
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_664
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_665
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6707
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6708
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6812
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_6988
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7131
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7181
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7232
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7233
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7487
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7553
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7718
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7741
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7855
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8140
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8480
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8520
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8839
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9015
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9025
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9154
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9162
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9257
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9267
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9292
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9324
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9332
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9351
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9360
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9372
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9419
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9446
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9467
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9486
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9529
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9577
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9585
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9590
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9595
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9600
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9626
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9635
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9691
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9701
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9717
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9718
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9725
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9751
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9778
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9787
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9789
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9797
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9815
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9841
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9864
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9900
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9922
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9933
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9947
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9960
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9986
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9993
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9994

# %%
df = pd.DataFrame(raw_data)
df.head()
display(df)
# Out:
#                     ID  Breed  \
# 0        n02115913_907  dhole
# 1       n02115913_4179  dhole
# 2       n02115913_1772  dhole
# 3       n02115913_2524  dhole
# 4       n02115913_1067  dhole
# ...                ...    ...
# 20575    n02115641_670  dingo
# 20576   n02115641_4800  dingo
# 20577  n02115641_13450  dingo
# 20578   n02115641_1228  dingo
# 20579  n02115641_12148  dingo
#
#                                                    Image  \
# 0      <PIL.Image.Image image mode=RGB size=195x215 a...
# 1      <PIL.Image.Image image mode=RGB size=214x159 a...
# 2      <PIL.Image.Image image mode=RGB size=273x197 a...
# 3      <PIL.Image.Image image mode=RGB size=393x372 a...
# 4      <PIL.Image.Image image mode=RGB size=348x482 a...
# ...                                                  ...
# 20575  <PIL.Image.Image image mode=RGB size=483x521 a...
# 20576  <PIL.Image.Image image mode=RGB size=178x275 a...
# 20577  <PIL.Image.Image image mode=RGB size=432x458 a...
# 20578  <PIL.Image.Image image mode=RGB size=329x316 a...
# 20579  <PIL.Image.Image image mode=RGB size=302x384 a...
#
#                                                     Path  Width  Height  Xmin  \
# 0        images/Images/n02115913-dhole/n02115913_907.jpg    500     333   196
# 1       images/Images/n02115913-dhole/n02115913_4179.jpg    500     333    90
# 2       images/Images/n02115913-dhole/n02115913_1772.jpg    500     326    92
# 3       images/Images/n02115913-dhole/n02115913_2524.jpg    500     375   106
# 4       images/Images/n02115913-dhole/n02115913_1067.jpg    362     504     0
# ...                                                  ...    ...     ...   ...
# 20575    images/Images/n02115641-dingo/n02115641_670.jpg    700     563    74
# 20576   images/Images/n02115641-dingo/n02115641_4800.jpg    500     281   166
# 20577  images/Images/n02115641-dingo/n02115641_13450.jpg    465     500    21
# 20578   images/Images/n02115641-dingo/n02115641_1228.jpg    400     329    32
# 20579  images/Images/n02115641-dingo/n02115641_12148.jpg    640     480   202
#
#        Xmax  Ymin  Ymax
# 0       391   108   323
# 1       304    91   250
# 2       365    89   286
# 3       499     0   372
# 4       348     6   488
# ...     ...   ...   ...
# 20575   557    26   547
# 20576   344     5   280
# 20577   453    40   498
# 20578   361    11   327
# 20579   504    94   478
#
# [20580 rows x 10 columns]

# %%
# Write out to csv
df.to_csv('data.csv', index=False)

print(df.to_csv(index=False))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df = pd.DataFrame(df["Image"])
df.head()
# Out:
#                                                Image
# 0  <PIL.Image.Image image mode=RGB size=195x215 a...
# 1  <PIL.Image.Image image mode=RGB size=214x159 a...
# 2  <PIL.Image.Image image mode=RGB size=273x197 a...
# 3  <PIL.Image.Image image mode=RGB size=393x372 a...
# 4  <PIL.Image.Image image mode=RGB size=348x482 a...

# %% [markdown]
# # Model

# %%
# Todo: Takes forever to run, not good

import numpy as np
import pandas as pd
from PIL import Image
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import NASNetLarge
from vit_keras import vit

# Function to extract features using NASNet
def extract_features_nasnet(image):
    nasnet_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    img = image.resize((224, 224))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = nasnet_model.predict(img_array)
    return features.flatten()

# Function to extract features using ViT
def extract_features_vit(image):
    vit_model = vit.vit_b32(image_size=256, activation=None, pretrained=True, include_top=False)
    img = image.resize((256, 256))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = vit_model.predict(img_array)
    return features.flatten()

# Load DataFrame with "Image" column containing PIL images
# Assuming df is your DataFrame
# df = pd.read_csv('your_data.csv')

# Extract features using NASNet and ViT
nasnet_features = df['Image'].apply(extract_features_nasnet)
vit_features = df['Image'].apply(extract_features_vit)

# Concatenate features
all_features = np.concatenate([nasnet_features.values, vit_features.values], axis=1)

# Perform PCA for dimensionality reduction
pca = PCA(n_components=100)  # Adjust number of components as needed
reduced_features = pca.fit_transform(all_features)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(reduced_features, df['Label'], test_size=0.2, random_state=42)

# Train SVM classifier
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)

# Evaluate SVM classifier
accuracy = svm_classifier.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# 2024-03-05 08:11:45.942781: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:45.992956: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:45.992994: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:45.995661: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:45.995701: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:45.995713: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:46.200369: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:46.200419: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:46.200425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-05 08:11:46.200447: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 08:11:46.200464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9550 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 7s 0us/step
# 2024-03-05 08:12:04.485996: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f963c62a480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f963c1e4540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 31
#      24     return features.flatten()
#      26 # Load DataFrame with "Image" column containing PIL images
#      27 # Assuming df is your DataFrame
#      28 # df = pd.read_csv('your_data.csv')
#      29
#      30 # Extract features using NASNet and ViT
# ---> 31 nasnet_features = df['Image'].apply(extract_features_nasnet)
#      32 vit_features = df['Image'].apply(extract_features_vit)
#      34 # Concatenate features
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 15, in extract_features_nasnet(image)
#      13 img = image.resize((224, 224))
#      14 img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
# ---> 15 features = nasnet_model.predict(img_array)
#      16 return features.flatten()
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:2655, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653 for step in data_handler.steps():
#    2654     callbacks.on_predict_batch_begin(step)
# -> 2655     tmp_batch_outputs = self.predict_function(iterator)
#    2656     if data_handler.should_sync:
#    2657         context.async_wait()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:888, in Function._call(self, *args, **kwds)
#     885 try:
#     886   # This is the first call of __call__, so we have to initialize.
#     887   initializers = []
# --> 888   self._initialize(args, kwds, add_initializers_to=initializers)
#     889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file4jtxjjp1.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:2425, in Model.make_predict_function.<locals>.step_function(model, iterator)
#    2420     run_step = tf.function(
#    2421         run_step, jit_compile=True, reduce_retracing=True
#    2422     )
#    2424 data = next(iterator)
# -> 2425 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    2426 outputs = reduce_per_replica(
#    2427     outputs, self.distribute_strategy, reduction="concat"
#    2428 )
#    2429 return outputs
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:1681, in StrategyBase.run(***failed resolving arguments***)
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:3271, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3269   kwargs = {}
#    3270 with self._container_strategy().scope():
# -> 3271   return self._call_for_each_replica(fn, args, kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:4069, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4067 def _call_for_each_replica(self, fn, args, kwargs):
#    4068   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:2413, in Model.make_predict_function.<locals>.step_function.<locals>.run_step(data)
#    2412 def run_step(data):
# -> 2413     outputs = model.predict_step(data)
#    2414     # Ensure counter is updated only if `test_step` succeeds.
#    2415     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:2381, in Model.predict_step(self, data)
#    2361 """The logic for one inference step.
#    2362
#    2363 This method can be overridden to support custom inference logic.
#    (...)
#    2378   `Model` on data.
#    2379 """
#    2380 x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 2381 return self(x, training=False)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:590, in Model.__call__(self, *args, **kwargs)
#     586         super().__call__(inputs, *copied_args, **copied_kwargs)
#     588     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 590 return super().__call__(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py:515, in Functional.call(self, inputs, training, mask)
#     496 @doc_controls.do_not_doc_inheritable
#     497 def call(self, inputs, training=None, mask=None):
#     498     """Calls the model on new inputs.
#     499
#     500     In this case `call` just reapplies
#    (...)
#     513         a list of tensors if there are more than one outputs.
#     514     """
# --> 515     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py:672, in Functional._run_internal_graph(self, inputs, training, mask)
#     669     continue  # Node is not computable, try skipping.
#     671 args, kwargs = node.map_arguments(tensor_dict)
# --> 672 outputs = node.layer(*args, **kwargs)
#     674 # Update tensor_dict.
#     675 for x_id, y in zip(
#     676     node.flat_output_ids, tf.nest.flatten(outputs)
#     677 ):
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:597, in BatchNormalizationBase.call(self, inputs, training, mask)
#     594         return outputs
#     596 if self.fused:
# --> 597     outputs = self._fused_batch_norm(
#     598         inputs, mask=mask, training=training
#     599     )
#     600     if self.virtual_batch_size is not None:
#     601         # Currently never reaches here since fused_batch_norm does not
#     602         # support virtual batching
#     603         outputs = undo_virtual_batching(outputs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:990, in BatchNormalizationBase._fused_batch_norm(self, inputs, mask, training)
#     978 def _fused_batch_norm_inference():
#     979     return tf.compat.v1.nn.fused_batch_norm(
#     980         inputs,
#     981         gamma,
#    (...)
#     987         data_format=self._data_format,
#     988     )
# --> 990 output, mean, variance = control_flow_util.smart_cond(
#     991     training, _fused_batch_norm_training, _fused_batch_norm_inference
#     992 )
#     993 variance = _maybe_add_or_remove_bessels_correction(
#     994     variance, remove=True
#     995 )
#     997 training_value = control_flow_util.constant_value(training)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/control_flow_util.py:108, in smart_cond(pred, true_fn, false_fn, name)
#     106 if isinstance(pred, tf.Variable):
#     107     return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108 return tf.__internal__.smart_cond.smart_cond(
#     109     pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110 )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/smart_cond.py:55, in smart_cond(pred, true_fn, false_fn, name)
#      53     return true_fn()
#      54   else:
# ---> 55     return false_fn()
#      56 else:
#      57   return cond.cond(pred, true_fn=true_fn, false_fn=false_fn,
#      58                    name=name)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:979, in BatchNormalizationBase._fused_batch_norm.<locals>._fused_batch_norm_inference()
#     978 def _fused_batch_norm_inference():
# --> 979     return tf.compat.v1.nn.fused_batch_norm(
#     980         inputs,
#     981         gamma,
#     982         beta,
#     983         mean=self.moving_mean,
#     984         variance=self.moving_variance,
#     985         epsilon=self.epsilon,
#     986         is_training=False,
#     987         data_format=self._data_format,
#     988     )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/nn_impl.py:1580, in fused_batch_norm(x, scale, offset, mean, variance, epsilon, data_format, is_training, name, exponential_avg_factor)
#    1577 if variance is None:
#    1578   variance = constant_op.constant([])
# -> 1580 y, running_mean, running_var, _, _, _ = gen_nn_ops.fused_batch_norm_v3(
#    1581     x,
#    1582     scale,
#    1583     offset,
#    1584     mean,
#    1585     variance,
#    1586     epsilon=epsilon,
#    1587     exponential_avg_factor=exponential_avg_factor,
#    1588     data_format=data_format,
#    1589     is_training=is_training,
#    1590     name=name)
#    1591 return y, running_mean, running_var
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_nn_ops.py:5206, in fused_batch_norm_v3(x, scale, offset, mean, variance, epsilon, exponential_avg_factor, data_format, is_training, name)
#    5204   is_training = True
#    5205 is_training = _execute.make_bool(is_training, "is_training")
# -> 5206 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    5207       "FusedBatchNormV3", x=x, scale=scale, offset=offset, mean=mean,
#    5208                           variance=variance, epsilon=epsilon,
#    5209                           exponential_avg_factor=exponential_avg_factor,
#    5210                           data_format=data_format, is_training=is_training,
#    5211                           name=name)
#    5212 _result = _outputs[:]
#    5213 if _execute.must_record_gradient():
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/op_def_library.py:776, in _apply_op_helper(op_type_name, name, **keywords)
#     771   _ExtractDefaultTypesAndAllowedTypes(op_def, default_type_attr_map,
#     772                                       allowed_list_attr_map)
#     774 # Requires that op_def has passed validation (using the C++
#     775 # ValidateOpDef() from ../framework/op_def_util.h).
# --> 776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
#     778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:445, in FuncGraph.as_default(self)
#     442 def as_default(self):
#     443   outer_cm = super().as_default()
# --> 445   @tf_contextlib.contextmanager
#     446   def inner_cm():
#     447     """Context manager for copying distribute.Strategy scope information."""
#     448     # pylint: disable=protected-access
#     449     # TODO(b/112906995, nareshmodi): distribution strategy depends on
#     450     # inheriting this stack from the default graph even in eager mode. Maybe
#     451     # it should be part of the eager context? This would also allow us to
#     452     # remove a get_default_graph() call from the function cache lookup.
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/tf_contextlib.py:32, in contextmanager(target)
#      22 """A tf_decorator-aware wrapper for `contextlib.contextmanager`.
#      23
#      24 Usage is identical to `contextlib.contextmanager`.
#    (...)
#      29   A callable that can be used inside of a `with` statement.
#      30 """
#      31 context_manager = _contextlib.contextmanager(target)
# ---> 32 return tf_decorator.make_decorator(target, context_manager, 'contextmanager')
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/tf_decorator.py:136, in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#     134 if decorator_name is None:
#     135   decorator_name = inspect.currentframe().f_back.f_code.co_name
# --> 136 decorator = TFDecorator(decorator_name, target, decorator_doc,
#     137                         decorator_argspec)
#     138 setattr(decorator_func, '_tf_decorator', decorator)
#     139 # Objects that are callables (e.g., a functools.partial object) may not have
#     140 # the following attributes.
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/tf_decorator.py:332, in TFDecorator.__init__(self, decorator_name, target, decorator_doc, decorator_argspec)
#     330 elif callable(target):
#     331   try:
# --> 332     self.__signature__ = inspect.signature(target)
#     333   except (TypeError, ValueError):
#     334     # Certain callables such as builtins can not be inspected for signature.
#     335     pass
#
# File /usr/lib/python3.11/inspect.py:3272, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3270 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3271     """Get a signature object for the passed callable."""
# -> 3272     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3273                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/lib/python3.11/inspect.py:3020, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3016 @classmethod
#    3017 def from_callable(cls, obj, *,
#    3018                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3019     """Constructs Signature for the given callable object."""
# -> 3020     return _signature_from_callable(obj, sigcls=cls,
#    3021                                     follow_wrapper_chains=follow_wrapped,
#    3022                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/lib/python3.11/inspect.py:2504, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2501             new_params = (first_wrapped_param,) + sig_params
#    2502             return sig.replace(parameters=new_params)
# -> 2504 if isfunction(obj) or _signature_is_functionlike(obj):
#    2505     # If it's a pure Python function, or an object that is duck type
#    2506     # of a Python function (Cython functions, for instance), then:
#    2507     return _signature_from_function(sigcls, obj,
#    2508                                     skip_bound_arg=skip_bound_arg,
#    2509                                     globals=globals, locals=locals, eval_str=eval_str)
#    2511 if _signature_is_builtin(obj):
#
# File /usr/lib/python3.11/inspect.py:378, in isfunction(object)
#     372         """Return true if the object is a getset descriptor.
#     373
#     374         getset descriptors are specialized descriptors defined in extension
#     375         modules."""
#     376         return False
# --> 378 def isfunction(object):
#     379     """Return true if the object is a user-defined function.
#     380
#     381     Function objects provide these attributes:
#    (...)
#     387         __annotations__ dict of parameter annotations
#     388         __kwdefaults__  dict of keyword only parameters with defaults"""
#     389     return isinstance(object, types.FunctionType)
#
# KeyboardInterrupt:

# %%
# save model
import pickle

# Assuming you have trained your SVM classifier and stored it in svm_classifier
# svm_classifier = YourSVMClassifier()

# Save the SVM classifier to a file
with open('svm_classifier.pkl', 'wb') as f:
    pickle.dump(svm_classifier, f)

# %%
# load model

import pickle

# Load the SVM classifier from the file
with open('svm_classifier.pkl', 'rb') as f:
    svm_classifier = pickle.load(f)

# Now svm_classifier contains your loaded SVM classifier object
