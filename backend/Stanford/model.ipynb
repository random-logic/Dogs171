# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
from PIL import Image

# %%
# print(os.listdir())
# x = os.path.join('annotations', 'Annotation')
# print(x)
# os.listdir(x)

# %%
# Define the paths
image_dir = 'images/Images'
annotation_dir = 'annotations/Annotation'

# Initialize an empty DataFrame to store the data
# data = {'ID': [],
#         'Breed': [],
#         'Image': [],
#         'Path': [],
#         'Width': [],
#         'Height': [],
#         'Xmin': [],
#         'Xmax': [],
#         'Ymin': [],
#         'Ymax': []}
# df = pd.DataFrame(data)
raw_data = []

# %%
#print(os.listdir(image_dir))
#print(os.listdir(annotation_dir))

# %%
# Traverse through image directory

i = 0
for breed_folder in os.listdir(image_dir):
#     if i > 10:  # Used for testing a subset
#         break
    breed_path = os.path.join(image_dir, breed_folder)
    if os.path.isdir(breed_path):
        breed = breed_folder.split('-')[-1].lower()  # Lowercase for uniformity
        print("Breed is:", breed) # FIXME: remove or comment
        
        # Identify each image in the subfolder
        for image_file in os.listdir(breed_path):
            if image_file.endswith('.jpg'):
                image_id = os.path.splitext(image_file)[0]
                image_path = os.path.join(breed_path, image_file)
                
                # Find corresponding annotation file
                annotation_file = os.path.join(annotation_dir, breed_folder, image_id)
                # print("Annotation file is:", annotation_file) # FIXME: remove or comment
                # Check if annotation file exists
                if os.path.exists(annotation_file):
                    # Read annotation file
                    with open(annotation_file, 'r') as f:
                        lines = f.readlines()
                    
                    # Extract annotation information
                    width = int(int(lines[7].split('>')[1].split('<')[0]))
                    #print(lines[7], width) # FIXME: remove
                    height = int(lines[8].split('>')[1].split('<')[0])
                    #print(lines[8], height) # FIXME: remove
                    xmin = int(lines[18].split('>')[1].split('<')[0])
                    #print(lines[18], xmin) # FIXME: remove
                    ymin = int(lines[19].split('>')[1].split('<')[0])
                    xmax = int(lines[20].split('>')[1].split('<')[0])
                    ymax = int(lines[21].split('>')[1].split('<')[0])
                    
                    # Open image and crop
                    img = Image.open(image_path)
                    img_cropped = img.crop((xmin, ymin, xmax, ymax))
                    #img.show()
                    #img_cropped.show()
                    
                    # Add the new entry to the list
                    raw_data.append({'ID': image_id,
                                      'Breed': breed,
                                      'Image': img_cropped,
                                      'Path': image_path,
                                      'Width': width,
                                      'Height': height,
                                      'Xmin': xmin,
                                      'Xmax': xmax,
                                      'Ymin': ymin,
                                      'Ymax': ymax})
                    
#     i+= 1
# Out:
# Breed is: clumber
# Breed is: toy_poodle
# Breed is: chihuahua
# Breed is: haired_fox_terrier
# Breed is: affenpinscher
# Breed is: bluetick
# Breed is: chesapeake_bay_retriever
# Breed is: kelpie
# Breed is: coated_wheaten_terrier
# Breed is: scottish_deerhound
# Breed is: weimaraner
# Breed is: toy_terrier
# Breed is: blenheim_spaniel
# Breed is: irish_water_spaniel
# Breed is: english_foxhound
# Breed is: borzoi
# Breed is: pomeranian
# Breed is: walker_hound
# Breed is: appenzeller
# Breed is: pekinese
# Breed is: doberman
# Breed is: redbone
# Breed is: bloodhound
# Breed is: bernese_mountain_dog
# Breed is: bouvier_des_flandres
# Breed is: brittany_spaniel
# Breed is: italian_greyhound
# Breed is: old_english_sheepdog
# Breed is: welsh_springer_spaniel
# Breed is: miniature_poodle
# Breed is: tan_coonhound
# Breed is: great_pyrenees
# Breed is: irish_terrier
# Breed is: french_bulldog
# Breed is: pug
# Breed is: basenji
# Breed is: english_springer
# Breed is: gordon_setter
# Breed is: beagle
# Breed is: ibizan_hound
# Breed is: shetland_sheepdog
# Breed is: german_shepherd
# Breed is: dingo
# Breed is: american_staffordshire_terrier
# Breed is: basset
# Breed is: tzu
# Breed is: norwich_terrier
# Breed is: miniature_pinscher
# Breed is: irish_setter
# Breed is: boston_bull
# Breed is: boxer
# Breed is: coated_retriever
# Breed is: australian_terrier
# Breed is: staffordshire_bullterrier
# Breed is: kuvasz
# Breed is: chow
# Breed is: miniature_schnauzer
# Breed is: bull_mastiff
# Breed is: rhodesian_ridgeback
# Breed is: rottweiler
# Breed is: whippet
# Breed is: eskimo_dog
# Breed is: yorkshire_terrier
# Breed is: vizsla
# Breed is: kerry_blue_terrier
# Breed is: briard
# Breed is: lakeland_terrier
# Breed is: cocker_spaniel
# Breed is: lhasa
# Breed is: cairn
# Breed is: keeshond
# Breed is: african_hunting_dog
# Breed is: newfoundland
# Breed is: giant_schnauzer
# Breed is: otterhound
# Breed is: pembroke
# Breed is: schipperke
# Breed is: sussex_spaniel
# Breed is: west_highland_white_terrier
# Breed is: standard_schnauzer
# Breed is: tibetan_mastiff
# Breed is: dhole
# Breed is: malinois
# Breed is: airedale
# Breed is: english_setter
# Breed is: saint_bernard
# Breed is: papillon
# Breed is: scotch_terrier
# Breed is: standard_poodle
# Breed is: samoyed
# Breed is: brabancon_griffon
# Breed is: irish_wolfhound
# Breed is: sealyham_terrier
# Breed is: leonberg
# Breed is: coated_retriever
# Breed is: komondor
# Breed is: cardigan
# Breed is: saluki
# Breed is: haired_pointer
# Breed is: japanese_spaniel
# Breed is: border_terrier
# Breed is: maltese_dog
# Breed is: great_dane
# Breed is: afghan_hound
# Breed is: groenendael
# Breed is: norfolk_terrier
# Breed is: entlebucher
# Breed is: tibetan_terrier
# Breed is: mexican_hairless
# Breed is: norwegian_elkhound
# Breed is: golden_retriever
# Breed is: border_collie
# Breed is: malamute
# Breed is: siberian_husky
# Breed is: bedlington_terrier
# Breed is: labrador_retriever
# Breed is: dandie_dinmont
# Breed is: silky_terrier
# Breed is: collie
# Breed is: greater_swiss_mountain_dog
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6514
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6569
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_66
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6650
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6656
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6671
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6746
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6892
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6921
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6927
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_6942
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7004
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7142
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7172
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_719
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7198
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7253
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7272
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7311
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7345
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7364
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7394
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7442
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7465
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7515
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7537
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7574
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_771
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7755
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7793
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7865
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_7941
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_797
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_804
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_807
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8089
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8224
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8248
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8350
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8365
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8417
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8447
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8449
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_850
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8507
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_851
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8616
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8658
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8735
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8745
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8756
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_8767
# Annotation file is: annotations/Annotation\n02085936-Maltese_dog\n02085936_
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7233
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7487
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7553
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7718
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7741
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_7855
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8140
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8480
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8520
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_8839
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9015
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9025
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9154
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9162
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9257
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9267
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9292
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9324
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9332
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9351
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9360
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9372
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9419
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9446
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9467
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9486
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9529
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9577
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9585
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9590
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9595
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9600
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9626
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9635
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9691
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9701
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9717
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9718
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9725
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9751
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9778
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9787
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9789
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9797
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9815
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9841
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9864
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9900
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9922
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9933
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9947
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9960
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9986
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9993
# Annotation file is: annotations/Annotation\n02088238-basset\n02088238_9994

# %%
df = pd.DataFrame(raw_data)
df.head()
display(df)
# Out:
#                    ID                       Breed  \
# 0      n02101556_1680                     clumber
# 1      n02101556_7677                     clumber
# 2      n02101556_5448                     clumber
# 3      n02101556_8039                     clumber
# 4      n02101556_5449                     clumber
# ...               ...                         ...
# 20575  n02107574_2523  greater_swiss_mountain_dog
# 20576  n02107574_1927  greater_swiss_mountain_dog
# 20577   n02107574_497  greater_swiss_mountain_dog
# 20578   n02107574_910  greater_swiss_mountain_dog
# 20579  n02107574_1261  greater_swiss_mountain_dog
#
#                                                    Image  \
# 0      <PIL.Image.Image image mode=RGB size=450x263 a...
# 1      <PIL.Image.Image image mode=RGB size=173x198 a...
# 2      <PIL.Image.Image image mode=RGB size=365x236 a...
# 3      <PIL.Image.Image image mode=RGB size=331x267 a...
# 4      <PIL.Image.Image image mode=RGB size=191x166 a...
# ...                                                  ...
# 20575  <PIL.Image.Image image mode=RGB size=369x175 a...
# 20576  <PIL.Image.Image image mode=RGB size=199x265 a...
# 20577  <PIL.Image.Image image mode=RGB size=444x461 a...
# 20578  <PIL.Image.Image image mode=RGB size=499x303 a...
# 20579  <PIL.Image.Image image mode=RGB size=499x292 a...
#
#                                                     Path  Width  Height  Xmin  \
# 0      images/Images/n02101556-clumber/n02101556_1680...    500     435    26
# 1      images/Images/n02101556-clumber/n02101556_7677...    360     240    75
# 2      images/Images/n02101556-clumber/n02101556_5448...    500     321    48
# 3      images/Images/n02101556-clumber/n02101556_8039...    500     375     2
# 4      images/Images/n02101556-clumber/n02101556_5449...    274     227    81
# ...                                                  ...    ...     ...   ...
# 20575  images/Images/n02107574-Greater_Swiss_Mountain...    500     375   130
# 20576  images/Images/n02107574-Greater_Swiss_Mountain...    200     280     0
# 20577  images/Images/n02107574-Greater_Swiss_Mountain...    500     486    43
# 20578  images/Images/n02107574-Greater_Swiss_Mountain...    500     333     0
# 20579  images/Images/n02107574-Greater_Swiss_Mountain...    500     375     0
#
#        Xmax  Ymin  Ymax
# 0       476   129   392
# 1       248    41   239
# 2       413    56   292
# 3       333   107   374
# 4       272    60   226
# ...     ...   ...   ...
# 20575   499   124   299
# 20576   199    14   279
# 20577   487    23   484
# 20578   499    29   332
# 20579   499    56   348
#
# [20580 rows x 10 columns]

# %%
# Write out to csv
df.to_csv('data.csv', index=False)

print(df.to_csv(index=False))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df = pd.DataFrame(df["Image"])
df.head()
# Out:
#                                                Image
# 0  <PIL.Image.Image image mode=RGB size=450x263 a...
# 1  <PIL.Image.Image image mode=RGB size=173x198 a...
# 2  <PIL.Image.Image image mode=RGB size=365x236 a...
# 3  <PIL.Image.Image image mode=RGB size=331x267 a...
# 4  <PIL.Image.Image image mode=RGB size=191x166 a...

# %% [markdown]
# # Model

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import NASNetLarge
from vit_keras import vit

# Function to extract features using NASNet
def extract_features_nasnet(image):
    nasnet_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    img = image.resize((224, 224))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = nasnet_model.predict(img_array)
    return features.flatten()

# Function to extract features using ViT
def extract_features_vit(image):
    vit_model = vit.vit_b32(image_size=256, activation=None, pretrained=True, include_top=False)
    img = image.resize((256, 256))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = vit_model.predict(img_array)
    return features.flatten()

# Load DataFrame with "Image" column containing PIL images
# Assuming df is your DataFrame
# df = pd.read_csv('your_data.csv')

# Extract features using NASNet and ViT
nasnet_features = df['Image'].apply(extract_features_nasnet)
vit_features = df['Image'].apply(extract_features_vit)

# Concatenate features
all_features = np.concatenate([nasnet_features.values, vit_features.values], axis=1)

# Perform PCA for dimensionality reduction
pca = PCA(n_components=100)  # Adjust number of components as needed
reduced_features = pca.fit_transform(all_features)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(reduced_features, df['Label'], test_size=0.2, random_state=42)

# Train SVM classifier
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)

# Evaluate SVM classifier
accuracy = svm_classifier.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 8
#       6 from sklearn.model_selection import train_test_split
#       7 from tensorflow.keras.applications import NASNetLarge
# ----> 8 from vit_keras import vit
#      10 # Function to extract features using NASNet
#      11 def extract_features_nasnet(image):
#
# File ~/anaconda3/envs/ecs171Dogs/lib/python3.11/site-packages/vit_keras/vit.py:6
#       3 import tensorflow as tf
#       4 import typing_extensions as tx
# ----> 6 from . import layers, utils
#       8 ConfigDict = tx.TypedDict(
#       9     "ConfigDict",
#      10     {
#    (...)
#      16     },
#      17 )
#      19 CONFIG_B: ConfigDict = {
#      20     "dropout": 0.1,
#      21     "mlp_dim": 3072,
#    (...)
#      24     "hidden_size": 768,
#      25 }
#
# File ~/anaconda3/envs/ecs171Dogs/lib/python3.11/site-packages/vit_keras/utils.py:11
#       9 import numpy as np
#      10 import scipy as sp
# ---> 11 import cv2
#      13 try:
#      14     import PIL
#
# File ~/anaconda3/envs/ecs171Dogs/lib/python3.11/site-packages/cv2/__init__.py:181
#     176             if DEBUG: print("Extra Python code for", submodule, "is loaded")
#     178     if DEBUG: print('OpenCV loader: DONE')
# --> 181 bootstrap()
#
# File ~/anaconda3/envs/ecs171Dogs/lib/python3.11/site-packages/cv2/__init__.py:153, in bootstrap()
#     149 if DEBUG: print("Relink everything from native cv2 module to cv2 package")
#     151 py_module = sys.modules.pop("cv2")
# --> 153 native_module = importlib.import_module("cv2")
#     155 sys.modules["cv2"] = py_module
#     156 setattr(py_module, "_native", native_module)
#
# File ~/anaconda3/envs/ecs171Dogs/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
