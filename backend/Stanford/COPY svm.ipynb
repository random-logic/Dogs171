# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import svm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('features.csv')
# display(df)
svm_train, svm_test = train_test_split(df, test_size=0.2)
X_svm_train, y_svm_train = svm_train.drop(columns=['Breed']), svm_train['Breed']
X_svm_test, y_svm_test = svm_test.drop(columns=['Breed']), svm_test['Breed']

clf = svm.SVC(kernel='rbf') # Linear Kernel
scaler = preprocessing.StandardScaler()
scaler.fit(X_svm_train)

Z_svm_train = scaler.transform(X_svm_train)
Z_svm_test = scaler.transform(X_svm_test)


clf.fit(Z_svm_train, y_svm_train)
y_pred = clf.predict(Z_svm_test)
print(classification_report(y_svm_test, y_pred))
# Out:
#                                 precision    recall  f1-score   support
#
#                  affenpinscher       0.77      0.84      0.81        32
#                   afghan_hound       1.00      0.94      0.97        52
#            african_hunting_dog       0.88      0.96      0.92        24
#                       airedale       0.79      0.87      0.83        39
# american_staffordshire_terrier       0.62      0.54      0.58        37
#                    appenzeller       0.60      0.65      0.62        23
#             australian_terrier       0.65      0.80      0.72        30
#                        basenji       0.88      0.86      0.87        44
#                         basset       0.79      0.81      0.80        37
#                         beagle       0.73      0.77      0.75        35
#             bedlington_terrier       0.88      1.00      0.93        35
#           bernese_mountain_dog       0.88      0.94      0.91        54
#               blenheim_spaniel       0.86      1.00      0.93        32
#                     bloodhound       0.85      0.88      0.86        40
#                       bluetick       0.76      0.90      0.82        31
#                  border_collie       0.62      0.86      0.72        28
#                 border_terrier       0.89      0.92      0.91        37
#                         borzoi       0.79      0.82      0.81        28
#                    boston_bull       0.89      0.81      0.85        42
#           bouvier_des_flandres       0.83      0.80      0.81        30
#                          boxer       0.85      0.76      0.80        29
#              brabancon_griffon       1.00      0.90      0.95        21
#                         briard       0.69      0.67      0.68        30
#               brittany_spaniel       0.85      0.71      0.77        24
#                   bull_mastiff       0.88      0.94      0.91        32
#                          cairn       0.78      0.88      0.83        33
#                       cardigan       0.76      0.67      0.71        33
#       chesapeake_bay_retriever       0.72      0.96      0.83        27
#                      chihuahua       0.59      0.76      0.67        21
#                           chow       0.98      0.94      0.96        48
#                        clumber       0.96      0.96      0.96        28
#               coated_retriever       0.83      0.88      0.85        33
#         coated_wheaten_terrier       0.76      0.88      0.81        32
#                 cocker_spaniel       0.87      0.87      0.87        31
#                         collie       0.71      0.31      0.43        32
#                 dandie_dinmont       0.94      0.83      0.88        36
#                          dhole       0.97      0.95      0.96        39
#                          dingo       0.78      0.79      0.78        39
#                       doberman       0.72      0.66      0.69        32
#               english_foxhound       0.87      0.70      0.78        37
#                 english_setter       0.85      0.85      0.85        34
#               english_springer       0.88      0.85      0.86        41
#                    entlebucher       0.91      0.75      0.82        53
#                     eskimo_dog       0.25      0.24      0.24        21
#                 french_bulldog       0.92      0.82      0.87        28
#                german_shepherd       0.83      0.80      0.81        30
#                giant_schnauzer       0.56      0.79      0.66        28
#               golden_retriever       0.88      0.85      0.86        33
#                  gordon_setter       1.00      0.90      0.95        29
#                     great_dane       0.71      0.77      0.74        26
#                 great_pyrenees       0.70      0.90      0.79        41
#     greater_swiss_mountain_dog       0.82      0.82      0.82        45
#                    groenendael       0.93      0.77      0.84        35
#             haired_fox_terrier       0.85      0.72      0.78        32
#                 haired_pointer       0.90      0.90      0.90        31
#                   ibizan_hound       0.86      0.86      0.86        42
#                   irish_setter       0.97      0.94      0.95        33
#                  irish_terrier       0.87      0.79      0.83        33
#            irish_water_spaniel       0.95      0.88      0.91        40
#                irish_wolfhound       0.66      0.73      0.69        45
#              italian_greyhound       0.64      0.85      0.73        33
#               japanese_spaniel       0.88      0.91      0.89        32
#                       keeshond       1.00      0.97      0.98        33
#                         kelpie       0.77      0.70      0.73        43
#             kerry_blue_terrier       0.89      0.83      0.86        30
#                       komondor       0.97      0.97      0.97        31
#                         kuvasz       0.83      0.62      0.71        24
#             labrador_retriever       0.86      0.83      0.85        30
#               lakeland_terrier       0.62      0.67      0.64        39
#                       leonberg       0.97      0.95      0.96        40
#                          lhasa       0.79      0.68      0.73        38
#                       malamute       0.83      0.60      0.69        42
#                       malinois       0.87      0.80      0.83        25
#                    maltese_dog       0.88      0.94      0.91        49
#               mexican_hairless       0.78      0.88      0.82        32
#             miniature_pinscher       0.86      0.79      0.82        38
#               miniature_poodle       0.60      0.50      0.55        36
#            miniature_schnauzer       0.52      0.52      0.52        29
#                   newfoundland       0.57      0.97      0.72        33
#                norfolk_terrier       0.74      0.67      0.70        42
#             norwegian_elkhound       0.97      0.94      0.95        33
#                norwich_terrier       0.90      0.74      0.81        35
#           old_english_sheepdog       0.93      1.00      0.96        27
#                     otterhound       0.94      0.78      0.85        37
#                       papillon       0.97      0.85      0.90        39
#                       pekinese       0.96      0.82      0.89        33
#                       pembroke       0.71      0.83      0.77        24
#                     pomeranian       0.98      0.94      0.96        48
#                            pug       0.80      0.80      0.80        46
#                        redbone       0.69      0.79      0.73        28
#            rhodesian_ridgeback       0.78      0.62      0.69        45
#                     rottweiler       0.79      0.87      0.83        30
#                  saint_bernard       0.97      0.91      0.94        32
#                         saluki       0.85      1.00      0.92        35
#                        samoyed       0.96      0.90      0.93        49
#                     schipperke       0.86      0.81      0.83        37
#                 scotch_terrier       0.90      0.69      0.78        26
#             scottish_deerhound       0.82      0.84      0.83        49
#               sealyham_terrier       1.00      0.91      0.96        35
#              shetland_sheepdog       0.67      0.81      0.73        27
#                 siberian_husky       0.55      0.68      0.61        40
#                  silky_terrier       0.83      0.65      0.73        37
#      staffordshire_bullterrier       0.56      0.67      0.61        30
#                standard_poodle       0.76      0.85      0.80        26
#             standard_schnauzer       0.69      0.50      0.58        40
#                 sussex_spaniel       1.00      0.97      0.98        30
#                  tan_coonhound       0.88      0.94      0.91        31
#                tibetan_mastiff       0.88      0.65      0.75        23
#                tibetan_terrier       0.88      0.80      0.84        46
#                     toy_poodle       0.65      0.53      0.59        32
#                    toy_terrier       0.84      0.78      0.81        27
#                            tzu       0.71      0.88      0.79        42
#                         vizsla       0.88      0.76      0.81        37
#                   walker_hound       0.65      0.60      0.62        25
#                     weimaraner       0.90      0.84      0.87        31
#         welsh_springer_spaniel       0.79      0.83      0.81        18
#    west_highland_white_terrier       0.81      0.98      0.88        43
#                        whippet       0.56      0.79      0.66        39
#              yorkshire_terrier       0.65      0.71      0.68        28
#
#                       accuracy                           0.81      4086
#                      macro avg       0.81      0.81      0.80      4086
#                   weighted avg       0.82      0.81      0.81      4086

# %%
# Define parameter grid for grid search
param_grid = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'gamma': [0.1, 0.01, 0.001],  # Kernel coefficient
    'kernel': ['rbf', 'linear']  # Kernel type
}

# %%
# Load data
df = pd.read_csv('features.csv')

# Split data into train and test sets
svm_train, svm_test = train_test_split(df, test_size=0.2)
X_svm_train, y_svm_train = svm_train.drop(columns=['Breed']), svm_train['Breed']
X_svm_test, y_svm_test = svm_test.drop(columns=['Breed']), svm_test['Breed']

# Scale features
scaler = StandardScaler()
scaler.fit(X_svm_train)
Z_svm_train = scaler.transform(X_svm_train)
Z_svm_test = scaler.transform(X_svm_test)

# Define SVM model
svm_model = SVC()

# Perform grid search
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(Z_svm_train, y_svm_train)

# Get best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Evaluate on test set with best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(Z_svm_test)
print("Classification Report:")
print(classification_report(y_svm_test, y_pred))
# Out:
# Best Parameters: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# Best Score: 0.8058992284256281
# Classification Report:
#                                 precision    recall  f1-score   support
#
#                  affenpinscher       0
#                       malinois       0.85      0.88      0.86        25
#                    maltese_dog       0.86      0.86      0.86        44
#               mexican_hairless       0.94      0.94      0.94        35
#             miniature_pinscher       0.82      0.90      0.86        40
#               miniature_poodle       0.48      0.37      0.42        30
#            miniature_schnauzer       0.81      0.81      0.81        27
#                   newfoundland       0.69      0.98      0.81        41
#                norfolk_terrier       0.67      0.93      0.78        28
#             norwegian_elkhound       0.95      0.95      0.95        43
#                norwich_terrier       0.85      0.69      0.76        42
#           old_english_sheepdog       0.86      0.91      0.89        34
#                     otterhound       1.00      0.83      0.91        29
#                       papillon       0.97      0.84      0.90        37
#                       pekinese       1.00      0.82      0.90        22
#                       pembroke       0.75      0.82      0.78        33
#                     pomeranian       0.87      0.93      0.90        44
#                            pug       0.80      0.84      0.82        38
#                        redbone       0.69      0.69      0.69        26
#            rhodesian_ridgeback       0.72      0.77      0.74        30
#                     rottweiler       0.91      0.89      0.90        47
#                  saint_bernard       0.97      0.95      0.96        39
#                         saluki       0.82      0.85      0.84        33
#                        samoyed       0.89      0.89      0.89        36
#                     schipperke       0.93      0.84      0.88        31
#                 scotch_terrier       0.83      0.69      0.75        29
#             scottish_deerhound       0.79      0.86      0.82        49
#               sealyham_terrier       0.92      0.97      0.95        37
#              shetland_sheepdog       0.66      0.84      0.74        25
#                 siberian_husky       0.44      0.78      0.56        27
#                  silky_terrier       0.85      0.56      0.68        39
#      staffordshire_bullterrier       0.68      0.63      0.66        30
#                standard_poodle       0.69      0.76      0.72        29
#             standard_schnauzer       0.89      0.53      0.67        32
#                 sussex_spaniel       0.97      0.91      0.94        33
#                  tan_coonhound       0.75      0.78      0.77        23
#                tibetan_mastiff       0.93      0.67      0.78        39
#                tibetan_terrier       0.73      0.82      0.77        39
#                     toy_poodle       0.61      0.70      0.66        27
#                    toy_terrier       0.80      0.77      0.79        43
#                            tzu       0.61      0.61      0.61        38
#                         vizsla       0.81      0.79      0.80        28
#                   walker_hound       0.58      0.54      0.56        28
#                     weimaraner       0.94      0.91      0.92        33
#         welsh_springer_spaniel       0.95      0.90      0.93        21
#    west_highland_white_terrier       0.97      0.97      0.97        35
#                        whippet       0.59      0.86      0.70        44
#              yorkshire_terrier       0.57      0.74      0.65        31
#
#                       accuracy                           0.81      4086
#                      macro avg       0.82      0.81      0.81      4086
#                   weighted avg       0.82      0.81      0.81      4086

# %%
# Get classification report
multiclass_report = classification_report(y_svm_test, y_pred)
print("Multiclass Classification Report:")
print(multiclass_report)

# Get confusion matrix
conf_matrix = confusion_matrix(y_svm_test, y_pred)

# Calculate percentage of correct predictions for each breed
breed_counts = df['Breed'].value_counts()
breed_accuracy = {}
for i in range(len(breed_counts)):
    breed = breed_counts.index[i]
    total_count = breed_counts[i]
    correct_count = conf_matrix[i][i]
    accuracy = correct_count / total_count * 100
    breed_accuracy[breed] = accuracy

# Sort breeds by accuracy
sorted_breeds = sorted(breed_accuracy.items(), key=lambda x: x[1], reverse=True)

print("\nSummary of Predicted Breeds Accuracy:")
for breed, accuracy in sorted_breeds:
    print(f"{breed}: {accuracy:.2f}%")

# Get the worst predicted breed
worst_breed = sorted_breeds[-1][0]
worst_accuracy = sorted_breeds[-1][1]
print("\nThe worst predicted breed is:", worst_breed, "with accuracy:", worst_accuracy)
