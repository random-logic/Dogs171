# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import svm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 from sklearn.preprocessing import StandardScaler
#       9 from sklearn.metrics import confusion_matrix
# ---> 10 from cuml.svm import SVC as cuSVC
#
# ModuleNotFoundError: No module named 'cuml'

# %%
df = pd.read_csv('features.csv')
# display(df)
svm_train, svm_test = train_test_split(df, test_size=0.2)
X_svm_train, y_svm_train = svm_train.drop(columns=['Breed']), svm_train['Breed']
X_svm_test, y_svm_test = svm_test.drop(columns=['Breed']), svm_test['Breed']

clf = svm.SVC(kernel='rbf') # Linear Kernel
scaler = preprocessing.StandardScaler()
scaler.fit(X_svm_train)

Z_svm_train = scaler.transform(X_svm_train)
Z_svm_test = scaler.transform(X_svm_test)


clf.fit(Z_svm_train, y_svm_train)
y_pred = clf.predict(Z_svm_test)
print(classification_report(y_svm_test, y_pred))
# Out:
#                                 precision    recall  f1-score   support
#
#                  affenpinscher       0.94      0.91      0.92        32
#                   afghan_hound       0.98      0.95      0.97        62
#            african_hunting_dog       0.91      0.91      0.91        33
#                       airedale       0.83      0.91      0.87        47
# american_staffordshire_terrier       0.56      0.60      0.58        30
#                    appenzeller       0.67      0.64      0.65        22
#             australian_terrier       0.75      0.83      0.79        29
#                        basenji       0.90      0.93      0.92        41
#                         basset       0.80      0.93      0.86        43
#                         beagle       0.81      0.68      0.74        37
#             bedlington_terrier       0.82      0.97      0.89        32
#           bernese_mountain_dog       0.94      0.98      0.96        49
#               blenheim_spaniel       0.90      0.97      0.94        39
#                     bloodhound       0.89      0.87      0.88        47
#                       bluetick       0.97      0.97      0.97        39
#                  border_collie       0.65      0.94      0.77        33
#                 border_terrier       0.88      0.94      0.91        32
#                         borzoi       0.92      0.96      0.94        25
#                    boston_bull       0.88      0.88      0.88        33
#           bouvier_des_flandres       0.92      0.82      0.87        40
#                          boxer       0.86      0.80      0.83        30
#              brabancon_griffon       0.97      0.85      0.90        33
#                         briard       0.93      0.74      0.82        38
#               brittany_spaniel       0.83      0.80      0.81        30
#                   bull_mastiff       0.79      0.81      0.80        27
#                          cairn       0.84      0.75      0.79        36
#                       cardigan       0.90      0.65      0.75        40
#       chesapeake_bay_retriever       0.76      0.81      0.79        32
#                      chihuahua       0.79      0.66      0.72        35
#                           chow       1.00      0.94      0.97        33
#                        clumber       0.97      0.94      0.95        32
#               coated_retriever       0.79      0.87      0.83        30
#         coated_wheaten_terrier       0.81      0.94      0.87        32
#                 cocker_spaniel       0.87      0.77      0.82        26
#                         collie       0.62      0.24      0.34        34
#                 dandie_dinmont       0.89      0.85      0.87        40
#                          dhole       0.93      0.93      0.93        28
#                          dingo       0.73      0.73      0.73        30
#                       doberman       0.78      0.76      0.77        41
#               english_foxhound       0.68      0.80      0.74        35
#                 english_setter       0.86      0.79      0.83        24
#               english_springer       0.83      0.81      0.82        31
#                    entlebucher       0.82      0.74      0.78        38
#             standard_schnauzer       0.95      0.55      0.70        38
#                 sussex_spaniel       1.00      0.96      0.98        46
#                  tan_coonhound       0.81      0.76      0.79        29
#                tibetan_mastiff       0.94      0.65      0.77        23
#                tibetan_terrier       0.72      0.85      0.78        39
#                     toy_poodle       0.62      0.45      0.53        22
#                    toy_terrier       0.79      0.71      0.75        31
#                            tzu       0.78      0.70      0.74        46
#                         vizsla       0.91      0.94      0.93        33
#                   walker_hound       0.73      0.53      0.62        30
#                     weimaraner       0.85      0.96      0.90        23
#         welsh_springer_spaniel       0.96      0.83      0.89        30
#    west_highland_white_terrier       0.85      0.98      0.91        46
#                        whippet       0.40      0.87      0.55        31
#              yorkshire_terrier       0.74      0.78      0.76        32
#
#                       accuracy                           0.82      4086
#                      macro avg       0.82      0.81      0.81      4086
#                   weighted avg       0.83      0.82      0.82      4086

# %%
# Define parameter grid for grid search
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': [1, 0.1, 0.01, 0.001],  # Kernel coefficient
    'kernel': ['rbf', 'linear']  # Kernel type
}

# %%
# Load data
df = pd.read_csv('features.csv')

# Split data into train and test sets
svm_train, svm_test = train_test_split(df, test_size=0.2)
X_svm_train, y_svm_train = svm_train.drop(columns=['Breed']), svm_train['Breed']
X_svm_test, y_svm_test = svm_test.drop(columns=['Breed']), svm_test['Breed']

# Scale features
scaler = StandardScaler()
scaler.fit(X_svm_train)
Z_svm_train = scaler.transform(X_svm_train)
Z_svm_test = scaler.transform(X_svm_test)

# Define SVM model
svm_model = SVC()

# Perform grid search
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(Z_svm_train, y_svm_train)

# Get best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Evaluate on test set with best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(Z_svm_test)
print("Classification Report:")
print(classification_report(y_svm_test, y_pred))

# %%
# Get classification report
multiclass_report = classification_report(y_svm_test, y_pred)
print("Multiclass Classification Report:")
print(multiclass_report)

# Get confusion matrix
conf_matrix = confusion_matrix(y_svm_test, y_pred)

# Calculate percentage of correct predictions for each breed
breed_counts = df['Breed'].value_counts()
breed_accuracy = {}
for i in range(len(breed_counts)):
    breed = breed_counts.index[i]
    total_count = breed_counts[i]
    correct_count = conf_matrix[i][i]
    accuracy = correct_count / total_count * 100
    breed_accuracy[breed] = accuracy

# Sort breeds by accuracy
sorted_breeds = sorted(breed_accuracy.items(), key=lambda x: x[1], reverse=True)

print("\nSummary of Predicted Breeds Accuracy:")
for breed, accuracy in sorted_breeds:
    print(f"{breed}: {accuracy:.2f}%")

# Get the worst predicted breed
worst_breed = sorted_breeds[-1][0]
worst_accuracy = sorted_breeds[-1][1]
print("\nThe worst predicted breed is:", worst_breed, "with accuracy:", worst_accuracy)
