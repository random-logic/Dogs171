# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
from PIL import Image

# %%
# print(os.listdir())
# x = os.path.join('annotations', 'Annotation')
# print(x)
# os.listdir(x)

# %%
# Define the paths
image_dir = 'images/Images'
annotation_dir = 'annotations/Annotation'

# Initialize an empty DataFrame to store the data
# data = {'ID': [],
#         'Breed': [],
#         'Image': [],
#         'Path': [],
#         'Width': [],
#         'Height': [],
#         'Xmin': [],
#         'Xmax': [],
#         'Ymin': [],
#         'Ymax': []}
# df = pd.DataFrame(data)
raw_data = []

# %%
#print(os.listdir(image_dir))
#print(os.listdir(annotation_dir))

# %%
# Traverse through image directory

i = 0
for breed_folder in os.listdir(image_dir):
#     if i > 10:  # Used for testing a subset
#         break
    breed_path = os.path.join(image_dir, breed_folder)
    if os.path.isdir(breed_path):
        breed = breed_folder.split('-')[-1].lower()  # Lowercase for uniformity
        print("Breed is:", breed) # FIXME: remove or comment
        
        # Identify each image in the subfolder
        for image_file in os.listdir(breed_path):
            if image_file.endswith('.jpg'):
                image_id = os.path.splitext(image_file)[0]
                image_path = os.path.join(breed_path, image_file)
                
                # Find corresponding annotation file
                annotation_file = os.path.join(annotation_dir, breed_folder, image_id)
                # print("Annotation file is:", annotation_file) # FIXME: remove or comment
                # Check if annotation file exists
                if os.path.exists(annotation_file):
                    # Read annotation file
                    with open(annotation_file, 'r') as f:
                        lines = f.readlines()
                    
                    # Extract annotation information
                    width = int(int(lines[7].split('>')[1].split('<')[0]))
                    #print(lines[7], width) # FIXME: remove
                    height = int(lines[8].split('>')[1].split('<')[0])
                    #print(lines[8], height) # FIXME: remove
                    xmin = int(lines[18].split('>')[1].split('<')[0])
                    #print(lines[18], xmin) # FIXME: remove
                    ymin = int(lines[19].split('>')[1].split('<')[0])
                    xmax = int(lines[20].split('>')[1].split('<')[0])
                    ymax = int(lines[21].split('>')[1].split('<')[0])
                    
                    # Open image and crop
                    img = Image.open(image_path)
                    img_cropped = img.crop((xmin, ymin, xmax, ymax))
                    #img.show()
                    #img_cropped.show()
                    
                    # Add the new entry to the list
                    raw_data.append({'ID': image_id,
                                      'Breed': breed,
                                      'Image': img_cropped,
                                      'Path': image_path,
                                      'Width': width,
                                      'Height': height,
                                      'Xmin': xmin,
                                      'Xmax': xmax,
                                      'Ymin': ymin,
                                      'Ymax': ymax})
                    
#     i+= 1
# Out:
# Breed is: dhole
# Breed is: scottish_deerhound
# Breed is: basset
# Breed is: briard
# Breed is: italian_greyhound
# Breed is: rottweiler
# Breed is: yorkshire_terrier
# Breed is: bernese_mountain_dog
# Breed is: pembroke
# Breed is: maltese_dog
# Breed is: malinois
# Breed is: bluetick
# Breed is: whippet
# Breed is: norwegian_elkhound
# Breed is: tan_coonhound
# Breed is: newfoundland
# Breed is: haired_fox_terrier
# Breed is: toy_terrier
# Breed is: gordon_setter
# Breed is: miniature_pinscher
# Breed is: cocker_spaniel
# Breed is: saint_bernard
# Breed is: pomeranian
# Breed is: cardigan
# Breed is: samoyed
# Breed is: norwich_terrier
# Breed is: french_bulldog
# Breed is: bull_mastiff
# Breed is: chesapeake_bay_retriever
# Breed is: appenzeller
# Breed is: english_setter
# Breed is: mexican_hairless
# Breed is: miniature_schnauzer
# Breed is: lhasa
# Breed is: pekinese
# Breed is: leonberg
# Breed is: bedlington_terrier
# Breed is: japanese_spaniel
# Breed is: borzoi
# Breed is: redbone
# Breed is: afghan_hound
# Breed is: schipperke
# Breed is: irish_setter
# Breed is: cairn
# Breed is: airedale
# Breed is: sealyham_terrier
# Breed is: sussex_spaniel
# Breed is: irish_terrier
# Breed is: great_pyrenees
# Breed is: brittany_spaniel
# Breed is: bloodhound
# Breed is: basenji
# Breed is: chow
# Breed is: affenpinscher
# Breed is: african_hunting_dog
# Breed is: staffordshire_bullterrier
# Breed is: old_english_sheepdog
# Breed is: kuvasz
# Breed is: english_springer
# Breed is: doberman
# Breed is: clumber
# Breed is: dandie_dinmont
# Breed is: border_collie
# Breed is: entlebucher
# Breed is: australian_terrier
# Breed is: tibetan_terrier
# Breed is: coated_retriever
# Breed is: ibizan_hound
# Breed is: beagle
# Breed is: blenheim_spaniel
# Breed is: otterhound
# Breed is: lakeland_terrier
# Breed is: walker_hound
# Breed is: boxer
# Breed is: haired_pointer
# Breed is: pug
# Breed is: scotch_terrier
# Breed is: kerry_blue_terrier
# Breed is: irish_wolfhound
# Breed is: english_foxhound
# Breed is: coated_retriever
# Breed is: siberian_husky
# Breed is: west_highland_white_terrier
# Breed is: standard_poodle
# Breed is: labrador_retriever
# Breed is: saluki
# Breed is: norfolk_terrier
# Breed is: border_terrier
# Breed is: toy_poodle
# Breed is: komondor
# Breed is: kelpie
# Breed is: shetland_sheepdog
# Breed is: silky_terrier
# Breed is: brabancon_griffon
# Breed is: vizsla
# Breed is: american_staffordshire_terrier
# Breed is: collie
# Breed is: rhodesian_ridgeback
# Breed is: chihuahua
# Breed is: eskimo_dog
# Breed is: keeshond
# Breed is: welsh_springer_spaniel
# Breed is: standard_schnauzer
# Breed is: malamute
# Breed is: weimaraner
# Breed is: boston_bull
# Breed is: german_shepherd
# Breed is: golden_retriever
# Breed is: coated_wheaten_terrier
# Breed is: papillon
# Breed is: groenendael
# Breed is: miniature_poodle
# Breed is: great_dane
# Breed is: tibetan_mastiff
# Breed is: tzu
# Breed is: bouvier_des_flandres
# Breed is: greater_swiss_mountain_dog
# Breed is: irish_water_spaniel
# Breed is: giant_schnauzer
# Breed is: dingo
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2287
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_23100
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2358
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2368
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2766
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2793
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2893
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2933
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_2935
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3149
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3174
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3402
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_347
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3493
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_356
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3774
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_380
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3832
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_3996
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4129
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_422
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4350
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4355
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4412
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4456
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4843
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_4984
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_499
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5053
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5087
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5106
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5125
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5197
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5522
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5555
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5590
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_5766
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_606
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6096
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6180
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6243
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6333
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6467
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6620
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6712
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6926
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_6956
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7027
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7068
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7235
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7302
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7769
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7817
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7944
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_7959
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8074
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8127
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8204
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8229
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8595
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_869
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8726
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8826
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_884
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_8902
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_904
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_9151
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_9316
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_937
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_9408
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_952
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_9756
# Annotation file is: annotations/Annotation\n02086079-Pekinese\n02086079_9847
# Breed is: tzu
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1011
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1016
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1059
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1078
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_10785
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1082
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_110
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11085
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11139
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1142
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11420
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11539
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11551
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11622
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11692
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1170
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11766
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_11959
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12003
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1205
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12057
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1215
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12314
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12315
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12342
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12348
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12480
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1249
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1259
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_126
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12650
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1267
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_12796
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1295
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1333
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_134
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_135
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1366
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1370
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1445
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1602
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1621
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1665
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1687
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1690
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1725
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1770
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1779
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1843
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1856
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_1859
# Annotation file is: annotations/Annotation\n02086240-Shih-Tzu\n02086240_
# 0        images/Images/n02115913-dhole/n02115913_907.jpg    500     333   196
# 1       images/Images/n02115913-dhole/n02115913_4179.jpg    500     333    90
# 2       images/Images/n02115913-dhole/n02115913_1772.jpg    500     326    92
# 3       images/Images/n02115913-dhole/n02115913_2524.jpg    500     375   106
# 4       images/Images/n02115913-dhole/n02115913_1067.jpg    362     504     0
# ...                                                  ...    ...     ...   ...
# 20575    images/Images/n02115641-dingo/n02115641_670.jpg    700     563    74
# 20576   images/Images/n02115641-dingo/n02115641_4800.jpg    500     281   166
# 20577  images/Images/n02115641-dingo/n02115641_13450.jpg    465     500    21
# 20578   images/Images/n02115641-dingo/n02115641_1228.jpg    400     329    32
# 20579  images/Images/n02115641-dingo/n02115641_12148.jpg    640     480   202
#
#        Xmax  Ymin  Ymax
# 0       391   108   323
# 1       304    91   250
# 2       365    89   286
# 3       499     0   372
# 4       348     6   488
# ...     ...   ...   ...
# 20575   557    26   547
# 20576   344     5   280
# 20577   453    40   498
# 20578   361    11   327
# 20579   504    94   478
#
# [20580 rows x 10 columns]

# %%
# Write out to csv
df.to_csv('data.csv', index=False)

print(df.to_csv(index=False))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df = pd.DataFrame(df["Image"])
df.head()
# Out:
#                                                Image
# 0  <PIL.Image.Image image mode=RGB size=195x215 a...
# 1  <PIL.Image.Image image mode=RGB size=214x159 a...
# 2  <PIL.Image.Image image mode=RGB size=273x197 a...
# 3  <PIL.Image.Image image mode=RGB size=393x372 a...
# 4  <PIL.Image.Image image mode=RGB size=348x482 a...

# %% [markdown]
# # Model

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import NASNetLarge
from vit_keras import vit

# Function to extract features using NASNet
def extract_features_nasnet(image):
    nasnet_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    img = image.resize((224, 224))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = nasnet_model.predict(img_array)
    return features.flatten()

# Function to extract features using ViT
def extract_features_vit(image):
    vit_model = vit.vit_b32(image_size=256, activation=None, pretrained=True, include_top=False)
    img = image.resize((256, 256))
    img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
    features = vit_model.predict(img_array)
    return features.flatten()

# Load DataFrame with "Image" column containing PIL images
# Assuming df is your DataFrame
# df = pd.read_csv('your_data.csv')

# Extract features using NASNet and ViT
nasnet_features = df['Image'].apply(extract_features_nasnet)
vit_features = df['Image'].apply(extract_features_vit)

# Concatenate features
all_features = np.concatenate([nasnet_features.values, vit_features.values], axis=1)

# Perform PCA for dimensionality reduction
pca = PCA(n_components=100)  # Adjust number of components as needed
reduced_features = pca.fit_transform(all_features)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(reduced_features, df['Label'], test_size=0.2, random_state=42)

# Train SVM classifier
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)

# Evaluate SVM classifier
accuracy = svm_classifier.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# 2024-03-05 07:19:30.667987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-05 07:19:30.668500: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 7s 0us/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe7702c32e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe6aa312980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 31
#      24     return features.flatten()
#      26 # Load DataFrame with "Image" column containing PIL images
#      27 # Assuming df is your DataFrame
#      28 # df = pd.read_csv('your_data.csv')
#      29
#      30 # Extract features using NASNet and ViT
# ---> 31 nasnet_features = df['Image'].apply(extract_features_nasnet)
#      32 vit_features = df['Image'].apply(extract_features_vit)
#      34 # Concatenate features
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 12, in extract_features_nasnet(image)
#      11 def extract_features_nasnet(image):
# ---> 12     nasnet_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#      13     img = image.resize((224, 224))
#      14     img_array = np.expand_dims(np.array(img) / 255.0, axis=0)
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/applications/nasnet.py:515, in NASNetLarge(input_shape, include_top, weights, input_tensor, pooling, classes, classifier_activation)
#     444 @keras_export(
#     445     "keras.applications.nasnet.NASNetLarge", "keras.applications.NASNetLarge"
#     446 )
#    (...)
#     454     classifier_activation="softmax",
#     455 ):
#     456     """Instantiates a NASNet model in ImageNet mode.
#     457
#     458     Reference:
#    (...)
#     513             backend that does not support separable convolutions.
#     514     """
# --> 515     return NASNet(
#     516         input_shape,
#     517         penultimate_filters=4032,
#     518         num_blocks=6,
#     519         stem_block_filters=96,
#     520         skip_reduction=True,
#     521         filter_multiplier=2,
#     522         include_top=include_top,
#     523         weights=weights,
#     524         input_tensor=input_tensor,
#     525         pooling=pooling,
#     526         classes=classes,
#     527         default_size=331,
#     528         classifier_activation=classifier_activation,
#     529     )
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/applications/nasnet.py:278, in NASNet(input_shape, penultimate_filters, num_blocks, stem_block_filters, skip_reduction, filter_multiplier, include_top, weights, input_tensor, pooling, classes, default_size, classifier_activation)
#     275 p = p0 if not skip_reduction else p
#     277 for i in range(num_blocks):
# --> 278     x, p = _normal_a_cell(
#     279         x,
#     280         p,
#     281         filters * filter_multiplier**2,
#     282         block_id="%d" % (2 * num_blocks + i + 1),
#     283     )
#     285 x = layers.Activation("relu")(x)
#     287 if include_top:
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/applications/nasnet.py:764, in _normal_a_cell(ip, p, filters, block_id)
#     761     x4 = layers.add([x4_1, x4_2], name=f"normal_add_4_{block_id}")
#     763 with backend.name_scope("block_5"):
# --> 764     x5 = _separable_conv_block(
#     765         h, filters, block_id=f"normal_left5_{block_id}"
#     766     )
#     767     x5 = layers.add([x5, h], name=f"normal_add_5_{block_id}")
#     769 x = layers.concatenate(
#     770     [p, x1, x2, x3, x4, x5],
#     771     axis=channel_dim,
#     772     name=f"normal_concat_{block_id}",
#     773 )
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/applications/nasnet.py:559, in _separable_conv_block(ip, filters, kernel_size, strides, block_id)
#     557 else:
#     558     conv_pad = "same"
# --> 559 x = layers.SeparableConv2D(
#     560     filters,
#     561     kernel_size,
#     562     strides=strides,
#     563     name=f"separable_conv_1_{block_id}",
#     564     padding=conv_pad,
#     565     use_bias=False,
#     566     kernel_initializer="he_normal",
#     567 )(x)
#     568 x = layers.BatchNormalization(
#     569     axis=channel_dim,
#     570     momentum=0.9997,
#     571     epsilon=1e-3,
#     572     name=f"separable_conv_1_bn_{block_id}",
#     573 )(x)
#     574 x = layers.Activation("relu")(x)
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/layers/convolutional/separable_conv2d.py:158, in SeparableConv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, depth_multiplier, activation, use_bias, depthwise_initializer, pointwise_initializer, bias_initializer, depthwise_regularizer, pointwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, pointwise_constraint, bias_constraint, **kwargs)
#     135 def __init__(
#     136     self,
#     137     filters,
#    (...)
#     156     **kwargs
#     157 ):
# --> 158     super().__init__(
#     159         rank=2,
#     160         filters=filters,
#     161         kernel_size=kernel_size,
#     162         strides=strides,
#     163         padding=padding,
#     164         data_format=data_format,
#     165         dilation_rate=dilation_rate,
#     166         depth_multiplier=depth_multiplier,
#     167         activation=activations.get(activation),
#     168         use_bias=use_bias,
#     169         depthwise_initializer=initializers.get(depthwise_initializer),
#     170         pointwise_initializer=initializers.get(pointwise_initializer),
#     171         bias_initializer=initializers.get(bias_initializer),
#     172         depthwise_regularizer=regularizers.get(depthwise_regularizer),
#     173         pointwise_regularizer=regularizers.get(pointwise_regularizer),
#     174         bias_regularizer=regularizers.get(bias_regularizer),
#     175         activity_regularizer=regularizers.get(activity_regularizer),
#     176         depthwise_constraint=constraints.get(depthwise_constraint),
#     177         pointwise_constraint=constraints.get(pointwise_constraint),
#     178         bias_constraint=constraints.get(bias_constraint),
#     179         **kwargs
#     180     )
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/layers/convolutional/base_separable_conv.py:127, in SeparableConv.__init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, depth_multiplier, activation, use_bias, depthwise_initializer, pointwise_initializer, bias_initializer, depthwise_regularizer, pointwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, pointwise_constraint, bias_constraint, trainable, name, **kwargs)
#     101 def __init__(
#     102     self,
#     103     rank,
#    (...)
#     125     **kwargs,
#     126 ):
# --> 127     super().__init__(
#     128         rank=rank,
#     129         filters=filters,
#     130         kernel_size=kernel_size,
#     131         strides=strides,
#     132         padding=padding,
#     133         data_format=data_format,
#     134         dilation_rate=dilation_rate,
#     135         activation=activations.get(activation),
#     136         use_bias=use_bias,
#     137         bias_initializer=initializers.get(bias_initializer),
#     138         bias_regularizer=regularizers.get(bias_regularizer),
#     139         activity_regularizer=regularizers.get(activity_regularizer),
#     140         bias_constraint=bias_constraint,
#     141         trainable=trainable,
#     142         name=name,
#     143         **kwargs,
#     144     )
#     145     self.depth_multiplier = depth_multiplier
#     146     self.depthwise_initializer = initializers.get(depthwise_initializer)
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:118, in Conv.__init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, conv_op, **kwargs)
#      94 def __init__(
#      95     self,
#      96     rank,
#    (...)
#     116     **kwargs,
#     117 ):
# --> 118     super().__init__(
#     119         trainable=trainable,
#     120         name=name,
#     121         activity_regularizer=regularizers.get(activity_regularizer),
#     122         **kwargs,
#     123     )
#     124     self.rank = rank
#     126     if isinstance(filters, float):
#
# File /opt/conda/lib/python3.11/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/engine/base_layer.py:388, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     386 self._updates = []
#     387 # Object to store all thread local layer properties.
# --> 388 self._thread_local = threading.local()
#     389 # A list of zero-argument lambdas which return Tensors, used for
#     390 # variable regularizers.
#     391 self._callable_losses = []
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/engine/base_layer.py:3153, in Layer.__setattr__(self, name, value)
#    3146 if (
#    3147     name == "_self_setattr_tracking"
#    3148     or not getattr(self, "_self_setattr_tracking", True)
#    3149     # Exclude @property.setters from tracking
#    3150     or hasattr(self.__class__, name)
#    3151 ):
#    3152     try:
# -> 3153         super(tf.__internal__.tracking.AutoTrackable, self).__setattr__(
#    3154             name, value
#    3155         )
#    3156     except AttributeError:
#    3157         raise AttributeError(
#    3158             (
#    3159                 'Can\'t set the attribute "{}", likely because it '
#    (...)
#    3162             ).format(name)
#    3163         )
#
# KeyboardInterrupt:
