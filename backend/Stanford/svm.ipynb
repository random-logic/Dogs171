# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import classification_report

df = pd.read_csv('features.csv')
# display(df)
svm_train, svm_test = train_test_split(df, test_size=0.2)
X_svm_train, y_svm_train = svm_train.drop(columns=['Breed']), svm_train['Breed']
X_svm_test, y_svm_test = svm_test.drop(columns=['Breed']), svm_test['Breed']

clf = svm.SVC(kernel='rbf') # Linear Kernel
scaler = preprocessing.StandardScaler()
scaler.fit(X_svm_train)

Z_svm_train = scaler.transform(X_svm_train)
Z_svm_test = scaler.transform(X_svm_test)


clf.fit(Z_svm_train, y_svm_train)
y_pred = clf.predict(Z_svm_test)
print(classification_report(y_svm_test, y_pred))
# Out:
#                                 precision    recall  f1-score   support
#
#                  affenpinscher       0.83      0.87      0.85        23
#                   afghan_hound       0.94      0.92      0.93        36
#            african_hunting_dog       1.00      0.95      0.98        43
#                       airedale       0.75      0.92      0.82        36
# american_staffordshire_terrier       0.51      0.79      0.62        34
#                    appenzeller       0.73      0.73      0.73        22
#             australian_terrier       0.80      0.85      0.82        41
#                        basenji       0.82      0.89      0.85        36
#                         basset       0.94      0.82      0.88        40
#                         beagle       0.77      0.87      0.81        38
#             bedlington_terrier       0.91      0.96      0.93        45
#           bernese_mountain_dog       0.98      0.92      0.95        51
#               blenheim_spaniel       0.88      0.95      0.91        39
#                     bloodhound       0.77      0.85      0.80        39
#                       bluetick       0.89      0.94      0.92        36
#                  border_collie       0.62      0.92      0.74        26
#                 border_terrier       0.93      0.93      0.93        28
#                         borzoi       0.88      0.82      0.85        28
#                    boston_bull       0.82      0.87      0.84        31
#           bouvier_des_flandres       0.84      0.86      0.85        37
#                          boxer       0.81      0.63      0.71        35
#              brabancon_griffon       0.97      0.88      0.92        33
#                         briard       0.89      0.80      0.84        30
#               brittany_spaniel       0.85      0.81      0.83        21
#                   bull_mastiff       0.86      0.73      0.79        26
#                          cairn       0.81      0.91      0.86        33
#                       cardigan       0.76      0.63      0.69        30
#       chesapeake_bay_retriever       0.72      0.79      0.75        29
#                      chihuahua       0.74      0.59      0.65        29
#                           chow       0.97      0.94      0.96        34
#                        clumber       1.00      0.89      0.94        27
#               coated_retriever       0.87      0.84      0.86        32
#         coated_wheaten_terrier       0.82      0.97      0.89        29
#                 cocker_spaniel       0.84      0.75      0.79        28
#                         collie       0.65      0.45      0.54        33
#                 dandie_dinmont       0.97      0.89      0.93        37
#                          dhole       0.94      0.94      0.94        35
#                          dingo       0.63      0.65      0.64        26
#                       doberman       0.76      0.68      0.72        28
#               english_foxhound       0.55      0.74      0.63        23
#                 english_setter       0.93      0.82      0.88        34
#               english_springer       0.80      0.80      0.80        30
#                    entlebucher       0.79      0.83      0.81        41
#                     eskimo_dog       0.48      0.33      0.39        33
#                 french_bulldog       0.89      0.76      0.82        33
#                german_shepherd       0.82      0.85      0.84        33
#                giant_schnauzer       0.56      0.93      0.70        29
#               golden_retriever       0.90      0.86      0.88        21
#                  gordon_setter       0.95      0.90      0.92        20
#                     great_dane       0.73      0.71      0.72        34
#                 great_pyrenees       0.74      0.88      0.81        52
#     greater_swiss_mountain_dog       0.62      0.62      0.62        21
#                    groenendael       0.91      0.94      0.92        32
#             haired_fox_terrier       0.88      0.66      0.75        32
#                 haired_pointer       0.91      0.86      0.89        37
#                   ibizan_hound       0.93      0.85      0.89        33
#                   irish_setter       0.95      0.83      0.88        23
#                  irish_terrier       0.70      0.82      0.76        34
#            irish_water_spaniel       0.82      0.97      0.89        29
#                irish_wolfhound       0.64      0.85      0.73        33
#              italian_greyhound       0.66      0.89      0.76        28
#               japanese_spaniel       0.95      0.93      0.94        40
#                       keeshond       1.00      1.00      1.00        34
#                         kelpie       0.73      0.73      0.73        33
#             kerry_blue_terrier       0.90      0.85      0.88        33
#                       komondor       0.96      0.84      0.90        31
#                         kuvasz       0.87      0.80      0.83        25
#             labrador_retriever       0.78      0.82      0.79        38
#               lakeland_terrier       0.56      0.68      0.61        40
#                       leonberg       0.97      0.97      0.97        37
#                          lhasa       0.70      0.57      0.63        46
#                       malamute       0.68      0.60      0.64        35
#                       malinois       0.85      0.66      0.74        35
#                    maltese_dog       0.79      0.94      0.85        47
#               mexican_hairless       0.84      0.93      0.89        29
#             miniature_pinscher       0.82      0.84      0.83        32
#               miniature_poodle       0.35      0.29      0.31        28
#            miniature_schnauzer       0.84      0.60      0.70        35
#                   newfoundland       0.79      0.76      0.78        41
#                norfolk_terrier       0.72      0.72      0.72        39
#             norwegian_elkhound       0.96      0.93      0.95        46
#                norwich_terrier       0.87      0.69      0.77        48
#           old_english_sheepdog       0.93      0.84      0.88        44
#                     otterhound       0.93      0.83      0.88        30
#                       papillon       0.97      1.00      0.99        35
#                       pekinese       0.92      0.75      0.83        32
#                       pembroke       0.86      0.85      0.85        52
#                     pomeranian       0.91      0.91      0.91        47
#                            pug       0.80      0.85      0.82        41
#                        redbone       0.73      0.82      0.77        33
#            rhodesian_ridgeback       0.61      0.66      0.63        38
#                     rottweiler       0.88      0.82      0.85        34
#                  saint_bernard       0.94      1.00      0.97        31
#                         saluki       0.91      0.78      0.84        41
#                        samoyed       0.83      0.90      0.86        39
#                     schipperke       0.88      0.91      0.89        32
#                 scotch_terrier       0.90      0.79      0.84        33
#             scottish_deerhound       0.86      0.86      0.86        49
#               sealyham_terrier       1.00      0.92      0.96        38
#              shetland_sheepdog       0.82      0.70      0.76        40
#                 siberian_husky       0.49      0.56      0.52        48
#                  silky_terrier       0.73      0.69      0.71        35
#      staffordshire_bullterrier       0.50      0.45      0.47        31
#                standard_poodle       0.74      0.70      0.72        33
#             standard_schnauzer       0.75      0.62      0.68        29
#                 sussex_spaniel       0.94      0.92      0.93        36
#                  tan_coonhound       0.81      0.93      0.86        27
#                tibetan_mastiff       0.90      0.77      0.83        35
#                tibetan_terrier       0.74      0.78      0.76        41
#                     toy_poodle       0.58      0.52      0.55        27
#                    toy_terrier       0.83      0.76      0.79        38
#                            tzu       0.55      0.69      0.61        32
#                         vizsla       0.92      0.77      0.84        31
#                   walker_hound       0.75      0.48      0.59        31
#                     weimaraner       0.88      0.85      0.87        34
#         welsh_springer_spaniel       0.86      0.86      0.86        42
#    west_highland_white_terrier       0.82      0.91      0.86        35
#                        whippet       0.37      0.69      0.48        29
#              yorkshire_terrier       0.77      0.71      0.74        42
#
#                       accuracy                           0.80      4086
#                      macro avg       0.81      0.80      0.80      4086
#                   weighted avg       0.81      0.80      0.80      4086
